# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_customers = pd.read_csv('drive/MyDrive/target_market_analysis_for_credit_cards/datasets/customers.csv')
df_cs = pd.read_csv('drive/MyDrive/target_market_analysis_for_credit_cards/datasets/credit_profiles.csv')
df_trans = pd.read_csv('drive/MyDrive/target_market_analysis_for_credit_cards/datasets/transactions.csv')

# %%
df_customers.sample(5)
# Out:
#      cust_id            name  gender  age location           occupation  \
# 25        26    Virat Shukla    Male   26    Rural           Freelancer
# 615      616    Swara Wadhwa  Female   19     City           Freelancer
# 889      890     Kabir Batra    Male   64     City       Business Owner
# 74        75  Aarohi Dwivedi  Female   25     City           Freelancer
# 449      450    Anika Rathod  Female   24   Suburb  Fullstack Developer
#
#      annual_income marital_status
# 25        239099.0         Single
# 615        10120.0        Married
# 889       413211.0        Married
# 74         28391.0        Married
# 449            NaN        Married

# %%
df_cs.sample(5)
# Out:
#      cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 72        73           323            0.858835             216.0
# 689      686           571            0.724806             698.0
# 418      419           788            0.180459            6658.0
# 868      865           789            0.757320           24319.0
# 661      659           448            0.316252              95.0
#
#      credit_inquiries_last_6_months  credit_limit
# 72                              1.0           NaN
# 689                             0.0        1250.0
# 418                             1.0       60000.0
# 868                             2.0       60000.0
# 661                             3.0         500.0

# %%
df_trans.sample(5)
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 128924   128925      490  2023-03-05           26   Meesho  Fashion & Apparel
# 414498   414499      763  2023-07-25           87  Alibaba             Sports
# 192752   192753      612  2023-04-06           31     Ebay  Fashion & Apparel
# 484347   484348      166  2023-08-29          378   Meesho        Electronics
# 445020   445021      397  2023-08-09           45   Meesho  Fashion & Apparel
#
#        payment_type
# 128924      Phonepe
# 414498         Gpay
# 192752  Credit Card
# 484347      Phonepe
# 445020   Debit Card

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cust_id         1000 non-null   int64
#  1   name            1000 non-null   object
#  2   gender          1000 non-null   object
#  3   age             1000 non-null   int64
#  4   location        1000 non-null   object
#  5   occupation      1000 non-null   object
#  6   annual_income   950 non-null    float64
#  7   marital_status  1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
df_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   tran_id           500000 non-null  int64
#  1   cust_id           500000 non-null  int64
#  2   tran_date         500000 non-null  object
#  3   tran_amount       500000 non-null  int64
#  4   platform          495059 non-null  object
#  5   product_category  500000 non-null  object
#  6   payment_type      500000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 26.7+ MB

# %%
df_cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cust_id                         1004 non-null   int64
#  1   credit_score                    1004 non-null   int64
#  2   credit_utilisation              1000 non-null   float64
#  3   outstanding_debt                1000 non-null   float64
#  4   credit_inquiries_last_6_months  1000 non-null   float64
#  5   credit_limit                    935 non-null    float64
# dtypes: float64(4), int64(2)
# memory usage: 47.2 KB

# %%
df_customers.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %%
df_trans.describe()
# Out:
#              tran_id        cust_id   tran_amount
# count  500000.000000  500000.000000  500000.00000
# mean   250000.500000     501.400428    3225.20733
# std    144337.711634     288.641924   13098.74276
# min         1.000000       1.000000       0.00000
# 25%    125000.750000     252.000000      64.00000
# 50%    250000.500000     502.000000     141.00000
# 75%    375000.250000     752.000000     397.00000
# max    500000.000000    1000.000000   69999.00000

# %%
df_cs.describe()
# Out:
#            cust_id  credit_score  credit_utilisation  outstanding_debt  \
# count  1004.000000   1004.000000         1000.000000       1000.000000
# mean    500.850598    588.655378            0.498950       9683.597000
# std     288.315670    152.575244            0.233139      25255.893671
# min       1.000000    300.000000            0.103761         33.000000
# 25%     251.750000    459.000000            0.293917        221.000000
# 50%     502.500000    601.000000            0.487422        550.000000
# 75%     749.250000    737.250000            0.697829      11819.500000
# max    1000.000000    799.000000            0.899648     209901.000000
#
#        credit_inquiries_last_6_months  credit_limit
# count                     1000.000000    935.000000
# mean                         1.955000  19235.561497
# std                          1.414559  24489.997195
# min                          0.000000    500.000000
# 25%                          1.000000    750.000000
# 50%                          2.000000   1250.000000
# 75%                          3.000000  40000.000000
# max                          4.000000  60000.000000

# %% [markdown]
# ## **Handling Null Values: Annual Income**

# %%
occupation_wise_income = df_customers.groupby('occupation')['annual_income'].describe()

# %%
occupation_wise_income
# Out:
#                      count           mean            std      min        25%  \
# occupation
# Accountant            16.0   64123.562500   12143.242631  27895.0   60953.25
# Artist                35.0   45267.685714   16846.786820   7621.0   35699.00
# Business Owner       278.0  264976.866906  110642.917610      2.0  179230.25
# Consultant            89.0   58989.786517   36774.344008      2.0   25109.00
# Data Scientist       167.0  135524.215569   44603.070338      2.0  111547.00
# Freelancer           223.0   76990.479821   69405.818225   5708.0   31785.00
# Fullstack Developer  142.0   78270.225352   46858.894748     50.0   34828.00
#
#                           50%        75%       max
# occupation
# Accountant            65265.0   70339.50   79953.0
# Artist                45794.0   55363.50   79267.0
# Business Owner       261191.5  355312.25  449346.0
# Consultant            58017.0   94672.00  117634.0
# Data Scientist       135759.0  171530.00  198981.0
# Freelancer            46759.0   99664.50  248597.0
# Fullstack Developer   76774.0  116843.25  158983.0

# %%
iqr = occupation_wise_income['75%'] - occupation_wise_income['25%']
occupation_wise_income['lower_limit'] = occupation_wise_income['25%'] - (1.5 * iqr)
occupation_wise_income['upper_limit'] = occupation_wise_income['75%'] + (1.5 * iqr)
occupation_wise_income['has_outliers'] = (occupation_wise_income['min'] >= occupation_wise_income['lower_limit']) & (occupation_wise_income['max'] <= occupation_wise_income['upper_limit'])

# %%
occupation_wise_income
# Out:
#                      count           mean            std      min        25%  \
# occupation
# Accountant            16.0   64123.562500   12143.242631  27895.0   60953.25
# Artist                35.0   45267.685714   16846.786820   7621.0   35699.00
# Business Owner       278.0  264976.866906  110642.917610      2.0  179230.25
# Consultant            89.0   58989.786517   36774.344008      2.0   25109.00
# Data Scientist       167.0  135524.215569   44603.070338      2.0  111547.00
# Freelancer           223.0   76990.479821   69405.818225   5708.0   31785.00
# Fullstack Developer  142.0   78270.225352   46858.894748     50.0   34828.00
#
#                           50%        75%       max  lower_limit  upper_limit  \
# occupation
# Accountant            65265.0   70339.50   79953.0    46873.875    84418.875
# Artist                45794.0   55363.50   79267.0     6202.250    84860.250
# Business Owner       261191.5  355312.25  449346.0   -84892.750   619435.250
# Consultant            58017.0   94672.00  117634.0   -79235.500   199016.500
# Data Scientist       135759.0  171530.00  198981.0    21572.500   261504.500
# Freelancer            46759.0   99664.50  248597.0   -70034.250   201483.750
# Fullstack Developer   76774.0  116843.25  158983.0   -88194.875   239866.125
#
#                      has_outliers
# occupation
# Accountant                  False
# Artist                       True
# Business Owner               True
# Consultant                   True
# Data Scientist              False
# Freelancer                  False
# Fullstack Developer          True

# %%
occ_wise_median_income = occupation_wise_income['50%']
occ_wise_median_income
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: 50%, dtype: float64

# %%
def get_annual_income(row):
  if pd.isnull(row['annual_income']):
    return occ_wise_median_income.loc[row['occupation']]
  else:
    return row['annual_income']

df_customers['annual_income'] = df_customers.apply(lambda row: get_annual_income(row), axis=1)

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cust_id         1000 non-null   int64
#  1   name            1000 non-null   object
#  2   gender          1000 non-null   object
#  3   age             1000 non-null   int64
#  4   location        1000 non-null   object
#  5   occupation      1000 non-null   object
#  6   annual_income   1000 non-null   float64
#  7   marital_status  1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # **Distribution of annual income**

# %%
sns.histplot(data=df_customers['annual_income'], kde=True)
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Outlier Remove : Annual income
# As per business requirements, no customer has income < 100

# %%
for index, row in df_customers.iterrows():
  if row['annual_income'] < 100:
    df_customers.at[index, 'annual_income'] = 100

# %%
df_customers['annual_income'].describe()

# %% [markdown]
# # Visualizations : Annual income

# %%
cat_cols = ['gender', 'location', 'occupation', 'marital_status']
num_rows = 3
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))
# Flatten the axes array to make it easier to iterate
axes = axes.flatten()
# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
  # Calculate the average annual income for each category
  avg_income_by_category = df_customers.groupby(cat_col)['annual_income'].mean().reset_index()

  # Sort the data by 'annual_income' before plotting
  sorted_data = avg_income_by_category.sort_values(by='annual_income', ascending=False)

  sns.barplot(x=cat_col, y='annual_income', data=sorted_data, errorbar=None, ax=axes[i], palette='tab10')
  axes[i].set_title(f'Average Annual Income by {cat_col}')
  axes[i].set_xlabel(cat_col)
  axes[i].set_ylabel('Average Annual Income')
  # Rotate x-axis labels for better readability
  axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
  # Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
  fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Handle Null Values: Age Column

# %%
df_customers.age.isnull().sum()

# %% [markdown]
# # Outlier Treatment: Age

# %%
min_age = df_customers.age.min()
max_age = df_customers.age.max()
min_age, max_age

# %%
plt.hist(df_customers['age'], bins=20, edgecolor='black')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Customer Age Distribution")
plt.axvline(min_age, color="red", label=f"Min Age: {min_age}")
plt.axvline(max_age, color="green", label=f"Max Age: {max_age}")
plt.legend()
plt.show()

# %% [markdown]
# Business understanding : 15 <= age <=80

# %%
df_customers[(df_customers.age<15)|(df_customers.age>80)]

# %%
outliers = df_customers[(df_customers.age<15)|(df_customers.age>80)]
outliers.shape

# %%
outliers.head(3)

# %%
median_age_per_occupation = df_customers.groupby('occupation')['age'].median()
median_age_per_occupation

# %%
for index, row in outliers.iterrows():
  if pd.notnull(row['age']):
    occupation = df_customers.at[index, 'occupation']
    df_customers.at[index, 'age'] = median_age_per_occupation[occupation]

# %%
df_customers[(df_customers.age<15)|(df_customers.age>80)]

# %%
df_customers.describe()

# %% [markdown]
# # Data Visualization: Age Column

# %%
# Define the bin edges and labels
bin_edges = [17, 25, 48, 65] # Adjust as needed
bin_labels = ['18-25', '26-48', '49-65']
# Use the cut function to bin and label the age column
df_customers['age_group'] = pd.cut(df_customers['age'], bins=bin_edges, labels=bin_labels)

# %%
df_customers.head()

# %%
age_group_counts = df_customers['age_group'].value_counts(normalize=True) * 100

# %%
plt.figure(figsize=(4, 4))
plt.pie(
 age_group_counts,
 labels=age_group_counts.index,
 explode=(0.1,0,0),
 autopct='%1.1f%%',
 shadow=True,
 startangle=140)
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Age Groups')
plt.show()

# %% [markdown]
# More than 50% of customer base are in in age group of 26 - 48 adn ~26% are of age group 18 - 25

# %%
customer_location_gender = df_customers.groupby(['location',
'gender']).size().unstack(fill_value=0)
# Create a stacked bar chart to visualize the distribution of payment types for each occupation
customer_location_gender.plot(kind='bar', stacked=True, figsize=(5,
4))
# Add labels and title
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Customer Distribution by Location and Gender')
# Show the bar chart
plt.legend(title='Payment Type', bbox_to_anchor=(1, 1)) # Add a legend
# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Exploring Credit Score table

# %%
df_cs.shape

# %%
df_cs['cust_id'].nunique()

# %%
df_cs[df_cs.duplicated('cust_id', keep=False)]

# %%
df_cs_clean_1 = df_cs.drop_duplicates(subset='cust_id', keep="last")
df_cs_clean_1.shape

# %% [markdown]
# # Data Cleaning Step 2: Handle Null Values

# %%
df_cs_clean_1.isnull().sum()

# %%
df_cs_clean_1[df_cs_clean_1.credit_limit.isnull()]

# %%
df_cs_clean_1['credit_limit'].unique()

# %%
df_cs_clean_1['credit_limit'].value_counts()

# %%
# Create a scatter plot
plt.figure(figsize=(20, 5))
plt.scatter(df_cs_clean_1['credit_limit'],
df_cs_clean_1['credit_score'], c='blue', marker='o', label='Data Points')

# Customize the plot
plt.title('Credit Score vs. Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Credit Score')

# Adjust the y-axis bin interval to 1000
plt.xticks(range(0, 90001, 5000))
plt.grid(True)

# Show the plot
plt.legend()
plt.show()

# %%
# Define bin ranges
bin_ranges = [300, 450, 500, 550, 600, 650, 700, 750, 800]
# Create labels for the bins
bin_labels = [f'{start}-{end-1}' for start, end in zip(bin_ranges, bin_ranges[1:])]
# Use pd.cut to assign data to bins
df_cs_clean_1['credit_score_range'] = pd.cut(df_cs_clean_1['credit_score'], bins=bin_ranges, labels=bin_labels, include_lowest=True, right=False)

# %%
df_cs_clean_1.head()

# %%
mode_df = df_cs_clean_1.groupby('credit_score_range')['credit_limit'].agg(lambda x: x.mode().iloc[0]).reset_index()
mode_df

# %%
# Merge the mode values back with the original DataFrame
df_cs_clean_2 = pd.merge(df_cs_clean_1, mode_df, on='credit_score_range', suffixes=('', '_mode'))
df_cs_clean_2.sample(3)

# %%
df_cs_clean_3 = df_cs_clean_2.copy()
df_cs_clean_3['credit_limit'].fillna(df_cs_clean_3['credit_limit_mode'], inplace=True)
df_cs_clean_3.shape

# %%
df_cs_clean_3.isnull().sum()

# %%
df_cs_clean_3.describe()

# %% [markdown]
# # Data Cleaning Step 3: Handle Outliers: outstanding_debt

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(x=df_cs_clean_3['outstanding_debt'])
plt.title('Box plot for outstanding debt')

# %%
df_cs_clean_3[df_cs_clean_3['outstanding_debt'] > df_cs_clean_3['credit_limit']]

# %%
df_cs_clean_3.loc[df_cs_clean_3['outstanding_debt'] > df_cs_clean_3['credit_limit'], 'outstanding_debt']

# %%
df_cs_clean_3.loc[df_cs_clean_3['outstanding_debt'] > df_cs_clean_3['credit_limit'], 'outstanding_debt'] = df_cs_clean_3['credit_limit']

# %%
df_cs_clean_3.describe()

# %% [markdown]
# # Data Exploration: Visualizing Correlation in Credit Score Table

# %%
df_customers.head(2)

# %%
df_cs_clean_3.head(2)

# %%
df_merged = df_customers.merge(df_cs_clean_3, on='cust_id', how='inner')
df_merged.head(2)
# Out:
#    cust_id           name  gender   age location      occupation  \
# 0        1  Manya Acharya  Female  51.0     City  Business Owner
# 1        2  Anjali Pandey  Female  47.0     City      Consultant
#
#    annual_income marital_status age_group  credit_score  credit_utilisation  \
# 0       358211.0        Married     49-65           749            0.585171
# 1        65172.0         Single     26-48           587            0.107928
#
#    outstanding_debt  credit_inquiries_last_6_months  credit_limit  \
# 0           19571.0                             0.0       40000.0
# 1            1250.0                             2.0        1250.0
#
#   credit_score_range  credit_limit_mode
# 0            700-749            40000.0
# 1            550-599             1250.0

# %%
numerical_cols = ['credit_score', 'credit_utilisation',
'outstanding_debt', 'credit_limit', 'annual_income','age']
correlation_matrix = df_merged[numerical_cols].corr()
correlation_matrix
# Out:
#                     credit_score  credit_utilisation  outstanding_debt  \
# credit_score            1.000000           -0.070445          0.680654
# credit_utilisation     -0.070445            1.000000          0.192838
# outstanding_debt        0.680654            0.192838          1.000000
# credit_limit            0.847952           -0.080493          0.810581
# annual_income           0.564593           -0.092149          0.543434
# age                     0.444917           -0.027713          0.444301
#
#                     credit_limit  annual_income       age
# credit_score            0.847952       0.564593  0.444917
# credit_utilisation     -0.080493      -0.092149 -0.027713
# outstanding_debt        0.810581       0.543434  0.444301
# credit_limit            1.000000       0.671775  0.510993
# annual_income           0.671775       1.000000  0.609903
# age                     0.510993       0.609903  1.000000

# %%
# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.8)
plt.title('Correlation Plot')
plt.show()

# %% [markdown]
#  high correlation between credit limit and credit score (~0.85)

# %%
# Just looking if there is any relation between annual_income and credit score
plt.figure(figsize=(5, 4))
sns.scatterplot(x='annual_income', y='credit_score', data=df_merged, alpha=0.5)
plt.title('Scatter Plot of Annual income vs credit score')
plt.xlabel('Annual Income')
plt.ylabel('Credit Score')
plt.show()

# %% [markdown]
# # Transactions Table

# %%
df_trans.shape
# Out:
# (500000, 7)

# %% [markdown]
# # Data Cleaning Step 1: Handle NULL Values: platform column

# %%
df_trans.isnull().sum()
# Out:
# tran_id                0
# cust_id                0
# tran_date              0
# tran_amount            0
# platform            4941
# product_category       0
# payment_type           0
# dtype: int64

# %%
df_trans[df_trans.platform.isnull()]
# Out:
#         tran_id  cust_id   tran_date  tran_amount platform   product_category  \
# 355         356       58  2023-01-01          237      NaN        Electronics
# 418         419      383  2023-01-01          338      NaN        Electronics
# 607         608      421  2023-01-01          700      NaN        Electronics
# 844         845      945  2023-01-01          493      NaN             Sports
# 912         913      384  2023-01-01           85      NaN  Fashion & Apparel
# ...         ...      ...         ...          ...      ...                ...
# 499579   499580      924  2023-09-05           31      NaN  Fashion & Apparel
# 499646   499647      944  2023-09-05        58445      NaN  Fashion & Apparel
# 499725   499726      620  2023-09-05           15      NaN             Sports
# 499833   499834      616  2023-09-05           97      NaN  Fashion & Apparel
# 499997   499998       57  2023-09-05          224      NaN   Garden & Outdoor
#
#        payment_type
# 355     Net Banking
# 418     Credit Card
# 607         Phonepe
# 844     Credit Card
# 912         Phonepe
# ...             ...
# 499579         Gpay
# 499646      Phonepe
# 499725  Net Banking
# 499833  Credit Card
# 499997      Phonepe
#
# [4941 rows x 7 columns]

# %%
sns.countplot(y='product_category', hue='platform', data=df_trans)

# %% [markdown]
# In all product categories Amazon is the platform that is used the most for making purchases

# %%
df_trans.platform.mode()

# %%
df_trans['platform'].fillna(df_trans.platform.mode()[0], inplace=True)

# %%
df_trans.isnull().sum()

# %% [markdown]
# # Data Cleaning Step 2: Treat Outliers: tran_amount

# %%
df_trans.describe()

# %%
df_trans_zero = df_trans[df_trans.tran_amount==0]
df_trans_zero.head(3)

# %%
df_trans_zero.shape

# %%
df_trans_zero['platform'].value_counts()

# %%
df_trans_zero[['platform','product_category','payment_type']].value_counts()

# %%
df_trans_1 = df_trans[(df_trans.platform=='Amazon') & (df_trans.product_category=="Electronics") & (df_trans.payment_type=="Credit Card")]
df_trans_1.shape

# %%
median_to_replace = df_trans_1[df_trans_1.tran_amount>0]['tran_amount'].median()
median_to_replace

# %%
df_trans['tran_amount'].replace(0,median_to_replace, inplace=True)

# %%
df_trans.tran_amount.describe()

# %%
Q1, Q3 = df_trans['tran_amount'].quantile([0.25, 0.75])
IQR = Q3 - Q1

# %%
lower = Q1 - 2 * IQR
upper = Q3 + 2 * IQR
lower, upper

# %%
df_trans[df_trans.tran_amount<upper].tran_amount.max()

# %%
df_trans[df_trans.tran_amount>upper].tran_amount.min()

# %%
df_trans_outliers = df_trans[df_trans.tran_amount>=upper]
df_trans_outliers

# %%
df_trans_normal = df_trans[df_trans.tran_amount<upper]
df_trans_normal

# %%
tran_mean_per_category = df_trans_normal.groupby("product_category")["tran_amount"].mean()
tran_mean_per_category

# %%
df_trans.loc[df_trans_outliers.index]

# %%
df_trans.loc[df_trans_outliers.index, 'tran_amount'] = df_trans_outliers['product_category'].map(tran_mean_per_category)
df_trans.loc[df_trans_outliers.index]

# %%
sns.histplot(x='tran_amount', data=df_trans, bins=20, kde=True)

# %% [markdown]
# # Data Visualization: Payment Type Distribution

# %%
sns.countplot(x=df_trans.payment_type, stat='percent')

# %%
df_merged_2 = df_merged.merge(df_trans, on='cust_id', how='inner')
df_merged_2.head(3)

# %%
df_merged_2.shape

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='age_group', hue='payment_type', data=df_merged_2,
palette='Set3')
plt.title('Distribution of Payment types across Age groups')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Payment Type', loc='upper right')
plt.show()

# %% [markdown]
# From above analysis, we can see that age group 18-25 has less exposure to credit cards
# compared to other groups

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
sns.countplot(x='age_group', hue="product_category", data=df_merged_2, ax=ax1)
ax1.set_title("Product Category Count By Age Group")
ax1.set_xlabel("Age Group")
ax1.set_ylabel("Count")
ax1.legend(title="Product Category", loc='upper right')
sns.countplot(x='age_group', hue="platform", data=df_merged_2, ax=ax2)
ax2.set_title("Platform Count By Age Group")
ax2.set_xlabel("Age Group")
ax2.set_ylabel("Count")
ax2.legend(title="Product Category", loc='upper right')
plt.show()

# %% [markdown]
# Observations:
# 1. Top 3 purchasing categories of customers in age group (18 -25) : Electronics, Fashion &
# Apparel, Beauty & personal care
# 2. Top platforms : Amazon, Flipkart, Alibaba

# %% [markdown]
# # Data Visualization: Average Transaction Amount

# %%
# List of categorical columns
cat_cols = ['payment_type', 'platform', 'product_category', 'marital_status', 'age_group']
num_rows = 3
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))
# Flatten the axes array to make it easier to iterate
axes = axes.flatten()
# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
 # Calculate the average annual income for each category
 avg_tran_amount_by_category = df_merged_2.groupby(cat_col)['tran_amount'].mean().reset_index()

 # Sort the data by 'annual_income' before plotting
 sorted_data = avg_tran_amount_by_category.sort_values(by='tran_amount', ascending=False)

 sns.barplot(x=cat_col, y='tran_amount', data=sorted_data, ci=None, ax=axes[i], palette='tab10')
 axes[i].set_title(f'Average transaction amount by {cat_col}')
 axes[i].set_xlabel(cat_col)
 axes[i].set_ylabel('Average transaction amount')
 # Rotate x-axis labels for better readability
 axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
# Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
 fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Further Analysis On Age Group

# %%
# Group the data by age group and calculate the average credit_limit and credit_score
age_group_metrics = df_merged.groupby('age_group')[['annual_income', 'credit_limit', 'credit_score']].mean().reset_index()
age_group_metrics

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))

# Plot 1: Average annual income by age group
sns.barplot(x='age_group', y='annual_income', data=age_group_metrics, palette='tab10', ax=ax1)
ax1.set_title('Average Annual Income by Age Group')
ax1.set_xlabel('Age Group')
ax1.set_ylabel('Average Annual Income')
ax1.tick_params(axis='x', rotation=0)

# Plot 2: Average Max Credit Limit by Age Group
sns.barplot(x='age_group', y='credit_limit', data=age_group_metrics, palette='hls', ax=ax2)
ax2.set_title('Average Credit Limit by Age Group')
ax2.set_xlabel('Age Group')
ax2.set_ylabel('Average Credit Limit')
ax2.tick_params(axis='x', rotation=0)

# Plot 3: Average Credit Score by Age Group
sns.barplot(x='age_group', y='credit_score', data=age_group_metrics, palette='viridis', ax=ax3)
ax3.set_title('Average Credit Score by Age Group')
ax3.set_xlabel('Age Group')
ax3.set_ylabel('Average Credit Score')
ax3.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Targeting Untapped market
#
# 1. People with age group of 18 -25 accounts to ~26% of customer base in the data
# 2. Avg annual income of this group is less than 50k
# 3. They don't have much credit history which is getting reflected in their credit score and
# credit limit
# 4. Usage of credit cards as payment type is relatively low compared to other groups
# 5. Top 3 most shopping products categories : Electronics, Fashion & Apparel, Beauty &
# Personal care
